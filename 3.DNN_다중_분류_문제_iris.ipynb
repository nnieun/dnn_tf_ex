# %% [markdown]
# # 실습2. 다중 분류 문제 해결하기
# - 분류 예측의 갯수가 3개 이상인 것

# %%
# ensorFlow가 시작하자마자 GPU 메모리를 거의 전부 선점하는 것을 막고 필요한 만큼 점진적으로 확보하게 한
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')

for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FukxkL%2FbtrK7Czk12T%2Fwk2oWuMLdXXgrgFoDiXSgk%2Fimg.jpg">
#
# - 아이리스는 꽃잎의 모양과 길이에 따라 여러 가지 품종으로 나뉨
# -  보면 품종마다 비슷해 보이는데요. 과연 딥러닝을 사용해서 이들을 구별해 낼 수 있을까?

# %% [markdown]
# ## 붓꽃 데이터 구조
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FblVkOE%2FbtrK6Ri8ILi%2F45WkL4FpIuZtkmhZcEdUIk%2Fimg.jpg">
#
# ### feature 정보
# - sepal length : 꽃받침 길이
# - sepal width : 꽃받침 너비
# - petal length : 꽃잎 길이
# - petal width : 꽃잎 길이

# %% [markdown]
# ## 데이터 준비

# %%
import pandas as pd

# %%
# 데이터 가져오기
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target  # 0,1,2

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# DataFrame 생성
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y
df['species'] = df['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %% [markdown]
# ## 상관도 그래프 그리기

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df, hue='species')
plt.show()

# %% [markdown]
# ## X, y 데이터 분할

# %%
# X데이터 
X = df.iloc[:, :4]
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y = df['target']

# %% [markdown]
# ## 데이터 전처리

# %%
# 스케일링
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled[:5]
# Out:
# array([[-0.90068117,  1.01900435, -1.34022653, -1.3154443 ],
#        [-1.14301691, -0.13197948, -1.34022653, -1.3154443 ],
#        [-1.38535265,  0.32841405, -1.39706395, -1.3154443 ],
#        [-1.50652052,  0.09821729, -1.2833891 , -1.3154443 ],
#        [-1.02184904,  1.24920112, -1.34022653, -1.3154443 ]])

# %% [markdown]
# ### 문자를 숫자형으로 바꾸기
# - one-hot encoding(원핫인코딩)
# - pd.get_dummies()
#
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FbmPutv%2FbtrK5xFBKxx%2FsbX5lPxQdPoiEl3MOUJCKk%2Fimg.jpg">

# %%
# 원-핫 인코딩 처리
y = pd.get_dummies(y)
print(y.head())
# Out:
#       0      1      2
# 0  True  False  False
# 1  True  False  False
# 2  True  False  False
# 3  True  False  False
# 4  True  False  False

# %% [markdown]
# ## 학습/테스트 데이터 셋으로 분할

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, 
    test_size=0.2, 
    random_state=88,
    stratify=y
)

# %% [markdown]
# ## 딥러닝 모델 만들기

# %% [markdown]
# ### 딥러닝 모델 구조 정의
# - 출력층의 노드수 3개(setosa, versicolor, verginica), 다항 분류
# - 활성함수(activation) : sfoftmax
# - 컴파일(compile) : categorical_crossentropy

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

# %%
# 모델 객체 생성
# 입력 4
# 은닉층1 노드 12
# 은닉층2 노드 8
# 출력 3

model = Sequential()

# 독립변수 (칼럼 개수) 4을 입력으로 넣음 
model.add(Input(shape=(4,)))

# 은닉층 
model.add(Dense(12, activation='relu', name='Dense_1')) #  name='Dense_1' 이건 선택
model.add(Dense(8, activation='relu', name='Dense_2')) 

# 출력층
model.add(Dense(3, activation='softmax', name='Dense_3'))

model.summary()  # 딥러닝 모델 구조를 보여줌
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Dense_1 (Dense)                 │ (None, 12)             │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_2 (Dense)                 │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_3 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 191 (764.00 B)
#  Trainable params: 191 (764.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 모델 컬파일

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 정의한 모델이 효과적으로 실행될 수 있도록, loss함수, 최적화 함수, 평가 방법 설정


model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %% [markdown]
# ### 모델 학습

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=5,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# I0000 00:00:1788163392.417746   41948 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_49989__.17
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.6146 - loss: 0.8801 - val_accuracy: 0.7500 - val_loss: 0.7304
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6458 - loss: 0.7816 - val_accuracy: 0.7500 - val_loss: 0.6316
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6458 - loss: 0.7083 - val_accuracy: 0.7500 - val_loss: 0.5563
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6562 - loss: 0.6511 - val_accuracy: 0.7500 - val_loss: 0.5038
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6562 - loss: 0.6067 - val_accuracy: 0.7500 - val_loss: 0.4599
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6562 - loss: 0.5706 - val_accuracy: 0.7500 - val_loss: 0.4224
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6667 - loss: 0.5413 - val_accuracy: 0.7917 - val_loss: 0.3956
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6667 - loss: 0.5167 - val_accuracy: 0.7917 - val_loss: 0.3707
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6771 - loss: 0.4957 - val_accuracy: 0.8333 - val_loss: 0.3529
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7396 - loss: 0.4772 - val_accuracy: 0.8750 - val_loss: 0.3421
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7708 - loss: 0.4593 - val_accuracy: 0.9167 - val_loss: 0.3297
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7917 - loss: 0.4447 - val_accuracy: 0.8750 - val_loss: 0.3133
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8229 - loss: 0.4305 - val_accuracy: 0.9583 - val_loss: 0.3025
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 0.4169 - val_accuracy: 0.9583 - val_loss: 0.2891
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 0.4046 - val_accuracy: 0.9583 - val_loss: 0.2783
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 0.3922 - val_accuracy: 0.9583 - val_loss: 0.2660
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8542 - loss: 0.3783 - val_accuracy: 0.9583 - val_loss: 0.2530
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8646 - loss: 0.3639 - val_accuracy: 0.9583 - val_loss: 0.2373
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8646 - loss: 0.3469 - val_accuracy: 0.9583 - val_loss: 0.2270
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8854 - loss: 0.3327 - val_accuracy: 0.9583 - val_loss: 0.2124
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8854 - loss: 0.3176 - val_accuracy: 0.9583 - val_loss: 0.1974
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9271 - loss: 0.3029 - val_accuracy: 0.9583 - val_loss: 0.1840
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9271 - loss: 0.2902 - val_accuracy: 1.0000 - val_loss: 0.1720
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9271 - loss: 0.2792 - val_accuracy: 1.0000 - val_loss: 0.1585
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9271 - loss: 0.2677 - val_accuracy: 1.0000 - val_loss: 0.1470
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9375 - loss: 0.2572 - val_accuracy: 1.0000 - val_loss: 0.1368
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9375 - loss: 0.2467 - val_accuracy: 1.0000 - val_loss: 0.1272
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9375 - loss: 0.2376 - val_accuracy: 1.0000 - val_loss: 0.1181
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9375 - loss: 0.2319 - val_accuracy: 1.0000 - val_loss: 0.1101
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9271 - loss: 0.2221 - val_accuracy: 1.0000 - val_loss: 0.1047
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9271 - loss: 0.2126 - val_accuracy: 1.0000 - val_loss: 0.0995
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.2063 - val_accuracy: 1.0000 - val_loss: 0.0942
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1974 - val_accuracy: 1.0000 - val_loss: 0.0890
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.1914 - val_accuracy: 1.0000 - val_loss: 0.0832
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.1849 - val_accuracy: 1.0000 - val_loss: 0.0766
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1789 - val_accuracy: 1.0000 - val_loss: 0.0729
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1747 - val_accuracy: 1.0000 - val_loss: 0.0691
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1687 - val_accuracy: 1.0000 - val_loss: 0.0683
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1662 - val_accuracy: 1.0000 - val_loss: 0.0627
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.1586 - val_accuracy: 1.0000 - val_loss: 0.0595
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1543 - val_accuracy: 1.0000 - val_loss: 0.0576
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.1521 - val_accuracy: 1.0000 - val_loss: 0.0543
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1492 - val_accuracy: 1.0000 - val_loss: 0.0488
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1422 - val_accuracy: 1.0000 - val_loss: 0.0469
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1391 - val_accuracy: 1.0000 - val_loss: 0.0457
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1360 - val_accuracy: 1.0000 - val_loss: 0.0427
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1332 - val_accuracy: 1.0000 - val_loss: 0.0413
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.1291 - val_accuracy: 1.0000 - val_loss: 0.0372
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1256 - val_accuracy: 1.0000 - val_loss: 0.0359
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1209 - val_accuracy: 1.0000 - val_loss: 0.0373
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1199 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1151 - val_accuracy: 1.0000 - val_loss: 0.0325
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1139 - val_accuracy: 1.0000 - val_loss: 0.0312
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1092 - val_accuracy: 1.0000 - val_loss: 0.0290
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1096 - val_accuracy: 1.0000 - val_loss: 0.0284
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1051 - val_accuracy: 1.0000 - val_loss: 0.0268
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1033 - val_accuracy: 1.0000 - val_loss: 0.0258
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.0998 - val_accuracy: 1.0000 - val_loss: 0.0253
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0979 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0967 - val_accuracy: 1.0000 - val_loss: 0.0229
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1071 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0902 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0924 - val_accuracy: 1.0000 - val_loss: 0.0219
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0904 - val_accuracy: 1.0000 - val_loss: 0.0207
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0889 - val_accuracy: 1.0000 - val_loss: 0.0197
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0860 - val_accuracy: 1.0000 - val_loss: 0.0184
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0872 - val_accuracy: 1.0000 - val_loss: 0.0175
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.0839 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0822 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0809 - val_accuracy: 1.0000 - val_loss: 0.0161
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0797 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0802 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0772 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0758 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0767 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0793 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0749 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0715 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0714 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0704 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0697 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0686 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0695 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0669 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0665 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0696 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0672 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0641 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.0634 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0633 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0625 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0629 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0628 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0615 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0601 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0604 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0587 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0616 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0579 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0570 - val_accuracy: 1.0000 - val_loss: 0.0069

# %% [markdown]
# # 모델 평가

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print(score)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9333 - loss: 0.0934
# [0.09341467171907425, 0.9333333373069763]

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt

# history는 model.fit()의 반환값
plt.figure(figsize=(12,4))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import numpy as np

# %% [markdown]
# ## Confusion Matrix

# %%
# X_test 데이터에 대한 확률값 예측
y_pred_proba = model.predict(X_test)

# 확률이 가장 높은 값의 위치 인덱스
y_pred = np.argmax(y_pred_proba, axis=1)

# y의 실제 값
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
print("\nConfusion Matrix:")
print(cm)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
#
# Confusion Matrix:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  2  8]]

# %% [markdown]
# ## 평가 레포트

# %%
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=iris.target_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       0.83      1.00      0.91        10
#    virginica       1.00      0.80      0.89        10
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.93      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %%
from sklearn.metrics import roc_auc_score

roc_auc = roc_auc_score(
    y_test,
    y_pred_proba,
    multi_class="ovr",
    average="macro"
)

print(roc_auc)
# Out:
# 1.0

# %%
# 학습 완료 했으면, gpu 메모리 해제, restart kernel
